# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Connect to Db2 database on Cloud using Python
#
# Estimated time needed: **15** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Import the ibm_db Python library
# *   Enter the database connection credentials
# *   Create the database connection
# *   Close the database connection

# %% [markdown]
# **Note:** Please follow the instructions given in the first Lab of this course to Create a database service instance of Db2 on Cloud and retrieve your database Service Credentials.
#
# ## Import the `ibm_db` Python library
#
# The `ibm_db` [API ](https://pypi.python.org/pypi/ibm_db/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01) provides a variety of useful Python functions for accessing and manipulating data in an IBM® data server database, including functions for connecting to a database, preparing and issuing SQL statements, fetching rows from result sets, calling stored procedures, committing and rolling back transactions, handling errors, and retrieving metadata.
#
# We first import the ibm_db library into our Python Application
#
# Execute the following cells by clicking within it and then
# press `Shift` and `Enter` keys simultaneously
#
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you may need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# Collecting ibm_db==3.1.0
#   Downloading ibm_db-3.1.0.tar.gz (797 kB)
#      |████████████████████████████████| 797 kB 4.0 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting ibm_db_sa==0.3.3
#   Downloading ibm_db_sa-0.3.3.tar.gz (24 kB)
# Collecting sqlalchemy>=0.7.3
#   Downloading SQLAlchemy-1.4.41-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 9.3 MB/s eta 0:00:01
# Collecting greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))))
#   Downloading greenlet-1.1.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#      |████████████████████████████████| 157 kB 13.4 MB/s eta 0:00:01
# Building wheels for collected packages: ibm-db, ibm-db-sa
#   Building wheel for ibm-db (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/ewittmyl/anaconda3/envs/general/bin/python /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /tmp/tmpvpmeyxco
#        cwd: /tmp/pip-install-zovgmvax/ibm-db
#   Complete output (770 lines):
#   Detected 64-bit Python
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-cpython-38
#   copying ibm_db_dbi.py -> build/lib.linux-x86_64-cpython-38
#   copying testfunctions.py -> build/lib.linux-x86_64-cpython-38
#   copying tests.py -> build/lib.linux-x86_64-cpython-38
#   creating build/lib.linux-x86_64-cpython-38/clidriver
#   copying clidriver/__init__.py -> build/lib.linux-x86_64-cpython-38/clidriver
#   creating build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_140_BindParamSelectStmt.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_213_FieldDisplaySize_04.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_checkBooleanType.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_110_FieldNum.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_011_DeleteRowCount.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_064_Tables_05.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_211_FieldDisplaySize_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_030_Result.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_155_FetchAssocSelect_05.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_130_PrepExecuteSelectStmt.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_trusted_context_pconnect.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157a_FetchAssocWithoutScrollableCursorErr.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_114_NumericTest_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_036_FetchRow_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_039_FetchRowIndexPosNested_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_231_FieldTypeName.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_createdbNX.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_195_InsertRetrieveXMLData_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_260_FetchTupleMany_07.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_081_ConnWrongUser.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_071_CloseSuccess.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_112_FieldNumDiffCaseColNames.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_150_FetchAssocSelect_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_158_FetchAssocNestedSelects_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_021_CommitDelete.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_143_BindParamInsertStmtNoneParam.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/__init__.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_154_AllFetches.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_250_FreeResult_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_101_InsertDeleteFieldCount.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_008_ColumnInfo.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_037_FetchRowIndexPos.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_007_pConnPassingOpts.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_040_FetchTuple.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_070_Close.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_049_InsertNoneParam.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_111_FieldNumAddCol.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_103_NumFieldsSelect_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_046_FetchTupleMany_05.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_156_FetchAssocNestedSelects_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_043_FetchTupleMany_03.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_221_100PersistentConns.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_051_SetAutocommit_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_006_ConnPassingOpts.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_062_Tables_03.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_261_FetchObjectAccess.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_decimal.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_trusted_context_connect.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_bool_callproc.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_recreateDB.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_065_FilterTableName.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_038_FetchRowIndexPosNested_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_014_KeysetDrivenCursorNegativeRow.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_153_FetchAssocSelect_04.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_060_Tables_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_002_ConnDbUncatalogedConn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_090_ConnmsgWrongDbAlias.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_InsertRetrieveDateTimeTypeColumn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_cursortype.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_03a_ResultNonExistCol.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6755_ExtraNULLChar_ResultCLOBCol.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_148_CallSPDiffBindPattern_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_024_ForeignKeys.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_execute_many.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_warn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_210_FieldDisplaySize_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_121_FieldNameAddCol.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6528_ScopingProblemBindParam.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_019_selectRowcountPrefetchPrepOpt.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_152_FetchAssocSelect_03.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_265_NoAffectedRows.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_010_UpdateRowCount.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_035_FetchRow_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_032_ResultIndexName.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_230_FieldTypePos.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_125_FieldNamePos_03.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_createDropDB.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_251_FreeResult_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_160_FetchBoth.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_048_FetchTupleBinaryData_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_201_MultipleRsltsetsDiffColDefs.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_err_executemany.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_116_ConnActive.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_132_ExecuteStatementArrayMultipleParams.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_053_AttrThruConn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_decfloat.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_212_FieldDisplaySize_03.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_091_ConnmsgWrongUser.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_311_InsertSelectDeleteNumLiterals.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_159a_FetchAssocSeveralRows_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_133_ExecuteLongInputParams.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_300_ServerInfo.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157b_FetchAssocScrollableCursor_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_146_CallSPINAndOUTParams.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_042_FetchTupleMany_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_SPInOutZero.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_061_Tables_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_001_ConnDb.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_196_InsertRetrieveXMLData_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_025_PrimaryKeys.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_157_FetchAssocScrollableCursor_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_047_FetchTupleMany_06.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_151_FetchAssocSelect_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_120_FieldName.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_023_ColumnPrivileges.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_016_InsertDeleteRowCount_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_122_FieldNameDiffCaseColNames.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_191_ColumnsTable_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_124_FieldNamePos_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_SPInOutBlob.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_031_ResultIndexPosition.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_005_ConnBadUserBadPwd.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_050_AutocommitStatus.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_034_FetchAssoc.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_200_MultipleRsltsetsUniformColDefs.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_041_FetchTupleMany_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_144_BindParamInsertStmtPARAM_FILE.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_092_ConnmsgWrongPwd.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_082_ConnWrongPwd.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_131_PrepareExecuteSelectStatementParams.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_147_PrepareWithWrongType.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_booleanInsertSelect.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_197_StatisticsIndexes.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_264_InsertRetrieveBIGINTTypeColumn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_setgetOption.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_018_selectRowcountPrefetchSetOpt.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_180_StmtErrMsg.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_190_ColumnsTable_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_currentschema.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_102_NumFieldsSelect_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_015_InsertDeleteRowCount_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_100_SelectDeleteInsertFieldCount.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_141_BindParamSelectStmtMultipleParams_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_003_NumAffectedRows.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_022_RollbackInsert.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_052_SetAutocommit_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_6561_InsertNULLValues.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_113_DateTest.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_045_FetchTupleBinaryData_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_013_KeysetDrivenCursorSelect02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_066_TableObjects.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_000_PrepareDb.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_115_NumericTest_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_240_FieldWidthPosName_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_044_FetchTupleMany_04.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_145_BindRetrieveNoneEmptyString.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_012_KeysetDrivenCursorSelect01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_017_selectRowcountPrefetchSTMTOpt.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_020_RollbackDelete.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_310_ClientInfo.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_162_FetchBothNestedSelects_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_159_FetchAssocSeveralRows_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_004_ConnWrongUserPwd.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_033_ResultOutSequenceColumn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_161_FetchBothNestedSelects_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_080_ConnWrongDbAlias.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_123_FieldNamePos_01.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_52949_TestSPIntVarcharXml.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_220_PersistentConn.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_054_CursorType.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_063_Tables_04.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_142_BindParamSelectStmtMultipleParams_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_232_FieldTypePosName.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   copying ibm_db_tests/test_241_FieldWidthPosName_02.py -> build/lib.linux-x86_64-cpython-38/ibm_db_tests
#   creating build/lib.linux-x86_64-cpython-38/certs
#   copying certs/__init__.py -> build/lib.linux-x86_64-cpython-38/certs
#   running egg_info
#   writing ibm_db.egg-info/PKG-INFO
#   writing dependency_links to ibm_db.egg-info/dependency_links.txt
#   writing top-level names to ibm_db.egg-info/top_level.txt
#   reading manifest file 'ibm_db.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.png' under directory 'ibm_db_tests'
#   warning: no files found matching '*.jpg' under directory 'ibm_db_tests'
#   warning: no files found matching '*' under directory 'ibm_db_dlls'
#   warning: no previously-included files found matching 'config.py'
#   adding license file 'LICENSE'
#   writing manifest file 'ibm_db.egg-info/SOURCES.txt'
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bin' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bin' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bin' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bin' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.bnd' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.bnd' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.bnd' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.bnd' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.cfg' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.cfg' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.cfg' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.cfg' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.cfgcache' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.cfgcache' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.cfgcache' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.cfgcache' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.alt' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.alt' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.conv.alt' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.alt' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.conv.ms' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.conv.ms' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.conv.ms' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.conv.ms' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.include' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.include' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.include' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.include' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.lib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.lib.icc' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc.C.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc.C.icc.icclib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.lib.icc.C.icc.icclib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc.C.icc.icclib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.lib.icc.N.icc.icclib' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.lib.icc.N.icc.icclib' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.lib.icc.N.icc.icclib' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.lib.icc.N.icc.icclib' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.license' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.license' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.license.UNIX' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.license.UNIX' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.license.UNIX' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.license.UNIX' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.msg' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.msg' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.msg' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.msg' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.properties.version' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.properties.version' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.properties.version' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.properties.version' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   /tmp/pip-build-env-h1kezuhc/overlay/lib/python3.8/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'clidriver.security64.plugin.IBM.client' as data is deprecated, please list it in `packages`.
#       !!
#
#
#       ############################
#       # Package would be ignored #
#       ############################
#       Python recognizes 'clidriver.security64.plugin.IBM.client' as an importable package,
#       but it is not listed in the `packages` configuration of setuptools.
#
#       'clidriver.security64.plugin.IBM.client' has been automatically added to the distribution only
#       because it may contain data files, but this behavior is likely to change
#       in future versions of setuptools (and therefore is considered deprecated).
#
#       Please make sure that 'clidriver.security64.plugin.IBM.client' is included as a package by using
#       the `packages` configuration field or the proper discovery methods
#       (for example by using `find_namespace_packages(...)`/`find_namespace:`
#       instead of `find_packages(...)`/`find:`).
#
#       You can read more about "package discovery" and "data files" on setuptools
#       documentation page.
#
#
#   !!
#
#     check.warn(importable)
#   creating build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2cli -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2diag -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2drdat -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2dsdcfgfill -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2ldcfg -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2lddrg -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2level -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2support -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   copying clidriver/bin/db2trc -> build/lib.linux-x86_64-cpython-38/clidriver/bin
#   creating build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2ajgrt.bnd -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2cli.bnd -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2cli.lst -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2clipk.bnd -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2clist.bnd -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   copying clidriver/bnd/db2spcdb.bnd -> build/lib.linux-x86_64-cpython-38/clidriver/bnd
#   creating build/lib.linux-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/DigiCertGlobalRootCA.arm -> build/lib.linux-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2cli.ini.sample -> build/lib.linux-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2dsdriver.cfg.sample -> build/lib.linux-x86_64-cpython-38/clidriver/cfg
#   copying clidriver/cfg/db2dsdriver.xsd -> build/lib.linux-x86_64-cpython-38/clidriver/cfg
#   creating build/lib.linux-x86_64-cpython-38/clidriver/cfgcache
#   copying clidriver/cfgcache/conlic.bin -> build/lib.linux-x86_64-cpython-38/clidriver/cfgcache
#   creating build/lib.linux-x86_64-cpython-38/clidriver/conv
#   creating build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/04370923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08500923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08501252.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08600923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/08630923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230437.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230850.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09230860.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231043.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231051.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231114.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231208.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231252.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09231275.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09241252.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/09370950.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/10430923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/10510923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/11140923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12080923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12520850.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12520923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/12750923.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/1388ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM00850.ucs -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM00923.ucs -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   copying clidriver/conv/alt/IBM01252.ucs -> build/lib.linux-x86_64-cpython-38/clidriver/conv/alt
#   creating build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0930ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0939ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0943ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/0954ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/1390ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/1399ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/5039ucs2.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   copying clidriver/conv/ms/ucs20943.cnv -> build/lib.linux-x86_64-cpython-38/clidriver/conv/ms
#   creating build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sql.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlca.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlcli.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlcli1.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlda.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlenv.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlext.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlstate.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlsystm.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqltypes.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlucode.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   copying clidriver/include/sqlunx.h -> build/lib.linux-x86_64-cpython-38/clidriver/include
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.so.58 -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libDB2xml4c.so.58.0 -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2.so.1 -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2clixml4c.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   copying clidriver/lib/libdb2clixml4c.so.1 -> build/lib.linux-x86_64-cpython-38/clidriver/lib
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8acmeidup_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8cms_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8dbfl_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8drld_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8iccs_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8kicc_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8km2_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8km_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8ldap_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8p11_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8ssl_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8sys_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   copying clidriver/lib/icc/libgsk8valn_64.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/C
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/C/icc
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   copying clidriver/lib/icc/C/icc/icclib/ICCSIG.txt -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   copying clidriver/lib/icc/C/icc/icclib/libicclib084.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/C/icc/icclib
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/N
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/N/icc
#   creating build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   copying clidriver/lib/icc/N/icc/icclib/ICCSIG.txt -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   copying clidriver/lib/icc/N/icc/icclib/libicclib085.so -> build/lib.linux-x86_64-cpython-38/clidriver/lib/icc/N/icc/icclib
#   creating build/lib.linux-x86_64-cpython-38/clidriver/license
#   copying clidriver/license/odbc_REDIST.txt -> build/lib.linux-x86_64-cpython-38/clidriver/license
#   copying clidriver/license/odbc_notices.txt -> build/lib.linux-x86_64-cpython-38/clidriver/license
#   creating build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_cs -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_de -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_el -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_en -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_es -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_fr -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_in -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_it -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ja -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ko -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_lt -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_pl -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_pt -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_ru -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_sl -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_tr -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_zh -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   copying clidriver/license/UNIX/odbc_LI_zh_TW -> build/lib.linux-x86_64-cpython-38/clidriver/license/UNIX
#   creating build/lib.linux-x86_64-cpython-38/clidriver/msg
#   creating build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2adm.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2admh.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2caem.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2cklog.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2cli.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clia1.lst -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clias.lst -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clih.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clit.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clp.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2clp2.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2diag.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2fodc.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2sql.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2sqlh.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2stt.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   copying clidriver/msg/en_US.iso88591/db2supp.mo -> build/lib.linux-x86_64-cpython-38/clidriver/msg/en_US.iso88591
#   creating build/lib.linux-x86_64-cpython-38/clidriver/properties
#   creating build/lib.linux-x86_64-cpython-38/clidriver/properties/version
#   copying clidriver/properties/version/ibm.com_IBM_Data_Server_Driver_for_ODBC_and_CLI-11.5.0.swidtag -> build/lib.linux-x86_64-cpython-38/clidriver/properties/version
#   creating build/lib.linux-x86_64-cpython-38/clidriver/security64
#   creating build/lib.linux-x86_64-cpython-38/clidriver/security64/plugin
#   creating build/lib.linux-x86_64-cpython-38/clidriver/security64/plugin/IBM
#   creating build/lib.linux-x86_64-cpython-38/clidriver/security64/plugin/IBM/client
#   copying clidriver/security64/plugin/IBM/client/IBMIAMauth.so -> build/lib.linux-x86_64-cpython-38/clidriver/security64/plugin/IBM/client
#   copying clidriver/security64/plugin/IBM/client/IBMkrb5.so -> build/lib.linux-x86_64-cpython-38/clidriver/security64/plugin/IBM/client
#   copying certs/ibm_certs.pem -> build/lib.linux-x86_64-cpython-38/certs
#   running build_ext
#   building 'ibm_db' extension
#   creating build/temp.linux-x86_64-cpython-38
#   gcc -pthread -B /home/ewittmyl/anaconda3/envs/general/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -Iclidriver/include -I/home/ewittmyl/anaconda3/envs/general/include/python3.8 -c ibm_db.c -o build/temp.linux-x86_64-cpython-38/ibm_db.o
#   error: command 'gcc' failed: No such file or directory
#   ----------------------------------------
#   ERROR: Failed building wheel for ibm-db
#   Building wheel for ibm-db-sa (setup.py) ... done
#   Created wheel for ibm-db-sa: filename=ibm_db_sa-0.3.3-py3-none-any.whl size=27410 sha256=c877ed1e32ec0381bdc19b1fc6ce3132f74d125701cc000b1f5d8bb344a183bd
#   Stored in directory: /home/ewittmyl/.cache/pip/wheels/ca/a9/b6/4f6402aa714d6e9903b79a15fbc3b2f02bf72da989b7708c18
# Successfully built ibm-db-sa
# Failed to build ibm-db
# ERROR: Could not build wheels for ibm-db which use PEP 517 and cannot be installed directly
# WARNING: Skipping sqlalchemy as it is not installed.
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24-cp38-cp38-manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 3.6 MB/s eta 0:00:01
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.24
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 757 kB/s eta 0:00:01
# Requirement already satisfied: six in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython-sql) (1.3.24)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython-sql) (7.18.1)
# Requirement already satisfied: backcall in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: decorator in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: pygments in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.1)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: pickleshare in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (50.3.0.post20201006)
# Requirement already satisfied: wcwidth in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ewittmyl/anaconda3/envs/general/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13700 sha256=0c9b2e0ef3f5e02809d80989a0bd01d1d2464cb3b5e6566746a75762c3d8d65a
#   Stored in directory: /home/ewittmyl/.cache/pip/wheels/46/60/6c/bb25d05df22906786206e901e9354bb3061061191116768bee
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2 sqlparse-0.4.3

# %%
import ibm_db
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-fe3bb08c8a05> in <module>
# ----> 1 import ibm_db
#
# ModuleNotFoundError: No module named 'ibm_db'

# %% [markdown]
# When the command above completes, the `ibm_db` library is loaded in your notebook.
#
# ## Identify the database connection credentials
#
# Connecting to dashDB or DB2 database requires the following information:
#
# *   Driver Name
# *   Database name
# *   Host DNS name or IP address
# *   Host port
# *   Connection protocol
# *   User ID (or username)
# *   User Password
#
# **Notice:** To obtain credentials please refer to the instructions given in the first Lab of this course
#
# Now enter your database credentials below and execute the cell with `Shift` + `Enter`

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "YourDb2Hostname" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "YourDb2Username"        # e.g. "abc12345"
dsn_pwd = "YoueDb2Password"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "YourPort"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %% [markdown]
# ## Create the DB2 database connection
#
# Ibm_db API uses the IBM Data Server Driver for ODBC and CLI APIs to connect to IBM DB2 and Informix.
#
# Lets build the dsn connection string using the credentials you entered above

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

#print the connection string to check correct values are specified
print(dsn)

# %% [markdown]
# Now establish the connection to the database

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )

# %% [markdown]
# Congratulations if you were able to connect successfuly. Otherwise check the error and try again.

# %%
#Retrieve Metadata for the Database Server
server = ibm_db.server_info(conn)

print ("DBMS_NAME: ", server.DBMS_NAME)
print ("DBMS_VER:  ", server.DBMS_VER)
print ("DB_NAME:   ", server.DB_NAME)

# %%
#Retrieve Metadata for the Database Client / Driver
client = ibm_db.client_info(conn)

print ("DRIVER_NAME:          ", client.DRIVER_NAME) 
print ("DRIVER_VER:           ", client.DRIVER_VER)
print ("DATA_SOURCE_NAME:     ", client.DATA_SOURCE_NAME)
print ("DRIVER_ODBC_VER:      ", client.DRIVER_ODBC_VER)
print ("ODBC_VER:             ", client.ODBC_VER)
print ("ODBC_SQL_CONFORMANCE: ", client.ODBC_SQL_CONFORMANCE)
print ("APPL_CODEPAGE:        ", client.APPL_CODEPAGE)
print ("CONN_CODEPAGE:        ", client.CONN_CODEPAGE)

# %% [markdown]
# ## Close the Connection
#
# We free all resources by closing the connection. Remember that it is always important to close connections so that we can avoid unused connections taking up resources.

# %%
ibm_db.close(conn)

# %% [markdown]
# ## Summary
#
# In this tutorial you established a connection to a DB2 database on Cloud database from a Python notebook using ibm_db API.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2022-01-01">Rav Ahuja</a>
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                 |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 2021-11-17        | 2.2     | Lakshmi    | Updated library                    |
# | 2021-07-09        | 2.1     | Malika     | Updated the connection string      |
# | 2020-08-28        | 2.0     | Lavanya    | Moved lab to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
